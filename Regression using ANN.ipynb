# %% [markdown]
# # Deep Neural Networks for Regression problems

# %% [markdown]
# Neural networks are well known for classification problems, for example, they are used in handwritten digits classification, but the question is will it be fruitful if we used them for regression problems?
#
# In this article I will use a deep neural network to predict house pricing using a dataset from Kaggle .
#
# You can download the dataset from [Here](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data)

# %% [markdown]
# ## Contents :
#     1- Process the dataset
#     2- Make the deep neural network
#     3- Train the DNN
#     4- Test the DNN
#     5- Compare the result from the DNN to another ML algorithm

# %% [markdown]
# **First of all, we will import the needed dependencies :**

# %%
import tensorflow as tf

# %%
# !pip install tensorflow==2.0.0
# Out:
# Requirement already satisfied: tensorflow==2.0.0 in /usr/local/lib/python3.7/dist-packages (2.0.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.21.5)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (0.2.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (0.37.1)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (2.0.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (0.8.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (3.17.3)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.13.3)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (3.3.0)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (2.0.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.44.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.0.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==2.0.0) (3.1.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (57.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (2.23.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (4.11.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (3.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==2.0.0) (1.5.2)

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

# %% [markdown]
# ## First : Processing the dataset
# We will not go deep in processing the dataset, all we want to do is getting the dataset ready to be fed into our models .
#
# We will get rid of any features with missing values, then we will encode the categorical features, that's it.

# %% [markdown]
# ### Load the dataset :
# * Load train and test data into pandas DataFrames
# * Combine train and test data to process them together

# %%
# mount google drive to collab notebook
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# change working DIR 
import os 
os.chdir("/content/drive/MyDrive/DeepL/3. Regression using ANN/DATA")

# %%
# !dir
# Out:
# data_description.txt  sample_submission.csv  test.csv  train.csv

# %%
def get_data():
    #get train data
    train_data_path ='train.csv'
    train = pd.read_csv(train_data_path)
    
    #get test data
    test_data_path ='test.csv'
    test = pd.read_csv(test_data_path)
    
    return train , test

def get_combined_data():
  #reading train data
  train , test = get_data()

  target = train.SalePrice
  train.drop(['SalePrice'],axis = 1 , inplace = True)

  combined = train.append(test)
  combined.reset_index(inplace=True)
  combined.drop(['index', 'Id'], inplace=True, axis=1)
  return combined, target

#Load train and test data into pandas DataFrames
train_data, test_data = get_data()

#Combine train and test data to process them together
combined, target = get_combined_data()

# %%
combined.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  2919.000000  2433.000000    2919.000000  2919.000000  2919.000000
# mean     57.137718    69.305795   10168.114080     6.089072     5.564577
# std      42.517628    23.344905    7886.996359     1.409947     1.113131
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7478.000000     5.000000     5.000000
# 50%      50.000000    68.000000    9453.000000     6.000000     5.000000
# 75%      70.000000    80.000000   11570.000000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  2919.000000   2919.000000  2896.000000  2918.000000  2918.000000  ...
# mean   1971.312778   1984.264474   102.201312   441.423235    49.582248  ...
# std      30.291442     20.894344   179.334253   455.610826   169.205611  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1953.500000   1965.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1993.000000     0.000000   368.500000     0.000000  ...
# 75%    2001.000000   2004.000000   164.000000   733.000000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1526.000000  ...
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  2918.000000  2919.000000  2919.000000    2919.000000  2919.000000
# mean    472.874572    93.709832    47.486811      23.098321     2.602261
# std     215.394815   126.526589    67.575493      64.244246    25.188169
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     320.000000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    26.000000       0.000000     0.000000
# 75%     576.000000   168.000000    70.000000       0.000000     0.000000
# max    1488.000000  1424.000000   742.000000    1012.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold
# count  2919.000000  2919.000000   2919.000000  2919.000000  2919.000000
# mean     16.062350     2.251799     50.825968     6.213087  2007.792737
# std      56.184365    35.663946    567.402211     2.714762     1.314964
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     576.000000   800.000000  17000.000000    12.000000  2010.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# let's define a function to get the columns that don't have any missing values

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %% [markdown]
# Get the columns that do not have any missing values .

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

# %% [markdown]
# Let's see how many columns we got

# %%
print ('Number of numerical columns with no nan values :',len(num_cols))
print ('Number of nun-numerical columns with no nan values :',len(cat_cols))
# Out:
# Number of numerical columns with no nan values : 25
# Number of nun-numerical columns with no nan values : 20

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %% [markdown]
# **The correlation between the features**

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True) 
plt.show()

# %% [markdown]
# From the correlation heatmap above, we see that about 15 features are highly correlated with the target.

# %% [markdown]
# **One Hot Encode The Categorical Features :**
#
# We will encode the categorical features using one hot encoding.

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df

# %%
print('There were {} columns before encoding categorical features'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
# Out:
# There were 45 columns before encoding categorical features
# There are 149 columns after encoding categorical features

# %% [markdown]
# Now, split back combined dataFrame to training data and test data

# %%
def split_combined():
    global combined
    train = combined[:1460]
    test = combined[1460:]

    return train , test

# %%
train, test = split_combined()

# %% [markdown]
# ## Second : Make the Deep Neural Network
#  * Define a sequential model
#  * Add some dense layers
#  * Use '**relu**' as the activation function in the hidden layers
#  * Use a '**normal**' initializer as the kernal_intializer
#            Initializers define the way to set the initial random weights of Keras layers.
#  * We will use mean_absolute_error as a loss function
#  * Define the output layer with only one node
#  * Use 'linear 'as the activation function for the output layer

# %%
model = Sequential()

# %% [markdown]
# **The Input Layer**

# %%
model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# %% [markdown]
# **The Hidden Layers**

# %%
model.add(Dense(256, kernel_initializer='normal',activation='relu'))
model.add(Dense(256, kernel_initializer='normal',activation='relu'))
model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# %% [markdown]
# **The Output Layer**

# %%
model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# %% [markdown]
# **Compile the network**

# %%
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               19200
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 184,065
# Trainable params: 184,065
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Define a checkpoint callback :**

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %% [markdown]
# ## Third : Train the model :

# %%
model.fit(train, target, epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 1168 samples, validate on 292 samples
# Epoch 1/500
#  864/1168 [=====================>........] - ETA: 0s - loss: 18944.0417 - mean_absolute_error: 18944.0410
# Epoch 00001: val_loss did not improve from 22307.00961
# 1168/1168 [==============================] - 0s 142us/sample - loss: 19186.8185 - mean_absolute_error: 19186.8184 - val_loss: 23050.3668 - val_mean_absolute_error: 23050.3672
# Epoch 2/500
#  896/1168 [======================>.......] - ETA: 0s - loss: 18411.7006 - mean_absolute_error: 18411.6992
# Epoch 00002: val_loss improved from 22307.00961 to 22145.48207, saving model to Weights-002--22145.48207.hdf5
# 1168/1168 [==============================] - 0s 196us/sample - loss: 19127.6320 - mean_absolute_error: 19127.6328 - val_loss: 22145.4821 - val_mean_absolute_error: 22145.4824
# Epoch 3/500
#  800/1168 [===================>..........] - ETA: 0s - loss: 18878.4688 - mean_absolute_error: 18878.4688
# Epoch 00003: val_loss did not improve from 22145.48207
# 1168/1168 [==============================] - 0s 154us/sample - loss: 17920.5614 - mean_absolute_error: 17920.5625 - val_loss: 25593.3268 - val_mean_absolute_error: 25593.3262
# Epoch 4/500
#  864/1168 [=====================>........] - ETA: 0s - loss: 18486.5453 - mean_absolute_error: 18486.5469
# Epoch 124/500
# 1120/1168 [===========================>..] - ETA: 0s - loss: 15921.3307 - mean_absolute_error: 15921.3320
# Epoch 00124: val_loss did not improve from 20258.98074
# 1168/1168 [==============================] - 0s 170us/sample - loss: 15998.5902 - mean_absolute_error: 15998.5928 - val_loss: 25312.5529 - val_mean_absolute_error: 25312.5508
# Epoch 125/500
#  992/1168 [========================>.....] - ETA: 0s - loss: 15451.5008 - mean_absolute_error: 15451.5020
# Epoch 00125: val_loss did not improve from 20258.98074
# 1168/1168 [==============================] - 0s 198us/sample - loss: 16172.1291 - mean_absolute_error: 16172.1289 - val_loss: 21920.9948 - val_mean_absolute_error: 21920.9961
# Epoch 126/500
# 1024/1168 [=========================>....] - ETA: 0s - loss: 16885.7538 - mean_absolute_error: 16885.7539
# Epoch 00126: val_loss did not improve from 20258.98074
# 1168/1168 [==============================] - 0s 186us/sample - loss: 16684.7533 - mean_absolute_error: 16684.7500 - val_loss: 21335.0213 - val_mean_absolute_error: 21335.0234
# Epoch 127/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 14990.1992 - mean_absolute_error: 14990.1992
# Epoch 00127: val_loss did not improve from 20258.98074
# 1168/1168 [==============================] - 0s 184us/sample - loss: 15554.0228 - mean_absolute_error: 15554.0225 - val_loss: 20873.0891 - val_mean_absolute_error: 20873.0898
# Epoch 128/500
# 1088/1168 [==========================>...] - ETA: 0s - loss: 16263.3102 - mean_absolute_error: 16263.3086
# Epoch 00128: val_loss did not improve from 20258.98074
# 1168/1168 [==============================] - 0s 183us/sample - loss: 16292.5265 - mean_absolute_error: 16292.5254 - val_loss: 20273.0948 - val_mean_absolute_error: 20273.0938
# Epoch 129/500
# 1024/1168 [=========================>....] - ETA: 0s - loss: 16099.2293 - mean_absolute_error: 16099.2295
# Epoch 00129: val_loss improved from 20258.98074 to 20208.06453, saving model to Weights-129--20208.06453.hdf5
# 1168/1168 [==============================] - 0s 247us/sample - loss: 15752.6724 - mean_absolute_error: 15752.6709 - val_loss: 20208.0645 - val_mean_absolute_error: 20208.0645
# Epoch 130/500
#  928/1168 [======================>.......] - ETA: 0s - loss: 15850.5174 - mean_absolute_error: 15850.5195
# Epoch 00130: val_loss did not improve from 20208.06453
# 1168/1168 [==============================] - 0s 202us/sample - loss: 15700.8407 - mean_absolute_error: 15700.8438 - val_loss: 20393.4390 - val_mean_absolute_error: 20393.4375
# Epoch 131/500
#  992/1168 [========================>.....] - ETA: 0s - loss: 16215.3302 - mean_absolute_error: 16215.3301
# Epoch 00131: val_loss improved from 20208.06453 to 20104.89501, saving model to Weights-131--20104.89501.hdf5
# 1168/1168 [==============================] - 0s 259us/sample - loss: 16212.0870 - mean_absolute_error: 16212.0859 - val_loss: 20104.8950 - val_mean_absolute_error: 20104.8945
# Epoch 132/500
#  960/1168 [=======================>......] - ETA: 0s - loss: 16467.0391 - mean_absolute_error: 16467.0391
# Epoch 00132: val_loss did not improve from 20104.89501
# 1168/1168 [==============================] - 0s 188us/sample - loss: 16618.4934 - mean_absolute_error: 16618.4941 - val_loss: 22676.1573 - val_mean_absolute_error: 22676.1562
# Epoch 133/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 17969.7399 - mean_absolute_error: 17969.7402
# Epoch 00133: val_loss did not improve from 20104.89501
# 1168/1168 [==============================] - 0s 175us/sample - loss: 18289.3585 - mean_absolute_error: 18289.3594 - val_loss: 21260.2068 - val_mean_absolute_error: 21260.2070
# Epoch 134/500
#  832/1168 [====================>.........] - ETA: 0s - loss: 17068.9619 - mean_absolute_error: 17068.9648
# Epoch 00134: val_loss improved from 20104.89501 to 19960.79500, saving model to Weights-134--19960.79500.hdf5
# 1168/1168 [==============================] - 0s 251us/sample - loss: 16783.1278 - mean_absolute_error: 16783.1289 - val_loss: 19960.7950 - val_mean_absolute_error: 19960.7949
# Epoch 135/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 16146.9225 - mean_absolute_error: 16146.9219
# Epoch 00135: val_loss did not improve from 19960.79500
# ...
# 1168/1168 [==============================] - 0s 249us/sample - loss: 13048.5741 - mean_absolute_error: 13048.5723 - val_loss: 19331.9723 - val_mean_absolute_error: 19331.9707
# Epoch 456/500
# 1152/1168 [============================>.] - ETA: 0s - loss: 13115.9741 - mean_absolute_error: 13115.9736
# Epoch 00456: val_loss did not improve from 18279.04869
# 1168/1168 [==============================] - 0s 218us/sample - loss: 13071.2404 - mean_absolute_error: 13071.2402 - val_loss: 19665.1333 - val_mean_absolute_error: 19665.1328
# Epoch 457/500
#  960/1168 [=======================>......] - ETA: 0s - loss: 15212.4779 - mean_absolute_error: 15212.4795
# Epoch 00457: val_loss did not improve from 18279.04869
# 1168/1168 [==============================] - 0s 234us/sample - loss: 15257.4970 - mean_absolute_error: 15257.4980 - val_loss: 20308.4096 - val_mean_absolute_error: 20308.4102
# Epoch 458/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 14277.7640 - mean_absolute_error: 14277.7646
# Epoch 00458: val_loss did not improve from 18279.04869
# 1168/1168 [==============================] - 0s 237us/sample - loss: 14486.5102 - mean_absolute_error: 14486.5107 - val_loss: 20866.7601 - val_mean_absolute_error: 20866.7578
# Epoch 459/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 12657.9094 - mean_absolute_error: 12657.9082
# Epoch 00459: val_loss did not improve from 18279.04869
# 1168/1168 [==============================] - 0s 231us/sample - loss: 12632.1940 - mean_absolute_error: 12632.1924 - val_loss: 19186.5562 - val_mean_absolute_error: 19186.5566
# Epoch 460/500
#  992/1168 [========================>.....] - ETA: 0s - loss: 13489.7138 - mean_absolute_error: 13489.7129
# Epoch 00460: val_loss did not improve from 18279.04869
# 1168/1168 [==============================] - 0s 244us/sample - loss: 13457.9971 - mean_absolute_error: 13457.9961 - val_loss: 18630.0524 - val_mean_absolute_error: 18630.0508
# Epoch 461/500
#  992/1168 [========================>.....] - ETA: 0s - loss: 12877.1706 - mean_absolute_error: 12877.1689
# Epoch 00461: val_loss did not improve from 18279.04869
# 1168/1168 [==============================] - 0s 228us/sample - loss: 13241.6442 - mean_absolute_error: 13241.6426 - val_loss: 23649.4205 - val_mean_absolute_error: 23649.4219
# Epoch 462/500
#  928/1168 [======================>.......] - ETA: 0s - loss: 15211.8700 - mean_absolute_error: 15211.8691
# Epoch 00462: val_loss did not improve from 18279.04869
# 1168/1168 [==============================] - 0s 201us/sample - loss: 15211.0386 - mean_absolute_error: 15211.0391 - val_loss: 19592.8602 - val_mean_absolute_error: 19592.8613
# Epoch 463/500
#  960/1168 [=======================>......] - ETA: 0s - loss: 13941.9478 - mean_absolute_error: 13941.9502
# Epoch 00463: val_loss did not improve from 18279.04869
# 1168/1168 [==============================] - 0s 246us/sample - loss: 14121.9556 - mean_absolute_error: 14121.9570 - val_loss: 20568.2235 - val_mean_absolute_error: 20568.2227
# Epoch 464/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 13301.0745 - mean_absolute_error: 13301.0742
# Epoch 00464: val_loss improved from 18279.04869 to 18242.63763, saving model to Weights-464--18242.63763.hdf5
# 1168/1168 [==============================] - 0s 296us/sample - loss: 13155.3542 - mean_absolute_error: 13155.3535 - val_loss: 18242.6376 - val_mean_absolute_error: 18242.6387
# Epoch 465/500
#  992/1168 [========================>.....] - ETA: 0s - loss: 15208.5713 - mean_absolute_error: 15208.5703
# Epoch 00465: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 234us/sample - loss: 15018.6089 - mean_absolute_error: 15018.6064 - val_loss: 21298.4350 - val_mean_absolute_error: 21298.4355
# Epoch 466/500
#  960/1168 [=======================>......] - ETA: 0s - loss: 15455.9992 - mean_absolute_error: 15455.9980
# Epoch 00466: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 246us/sample - loss: 15812.1813 - mean_absolute_error: 15812.1797 - val_loss: 21661.0508 - val_mean_absolute_error: 21661.0508
# Epoch 467/500
#  928/1168 [======================>.......] - ETA: 0s - loss: 13155.3295 - mean_absolute_error: 13155.3311
# Epoch 00467: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 243us/sample - loss: 13318.8116 - mean_absolute_error: 13318.8135 - val_loss: 19248.4979 - val_mean_absolute_error: 19248.4980
# Epoch 468/500
# 1024/1168 [=========================>....] - ETA: 0s - loss: 12713.1985 - mean_absolute_error: 12713.2002
# Epoch 00468: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 236us/sample - loss: 13024.4452 - mean_absolute_error: 13024.4473 - val_loss: 18520.4228 - val_mean_absolute_error: 18520.4238
# Epoch 469/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 12882.4094 - mean_absolute_error: 12882.4092
# Epoch 00469: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 229us/sample - loss: 12877.0001 - mean_absolute_error: 12877.0000 - val_loss: 19068.1346 - val_mean_absolute_error: 19068.1328
# Epoch 470/500
#  992/1168 [========================>.....] - ETA: 0s - loss: 12990.7018 - mean_absolute_error: 12990.7021
# Epoch 00470: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 246us/sample - loss: 13411.8061 - mean_absolute_error: 13411.8066 - val_loss: 21735.2034 - val_mean_absolute_error: 21735.2012
#  896/1168 [======================>.......] - ETA: 0s - loss: 13417.2417 - mean_absolute_error: 13417.2422
# Epoch 00480: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 245us/sample - loss: 13104.6054 - mean_absolute_error: 13104.6055 - val_loss: 18720.6818 - val_mean_absolute_error: 18720.6816
# Epoch 481/500
#  896/1168 [======================>.......] - ETA: 0s - loss: 12693.6371 - mean_absolute_error: 12693.6357
# Epoch 00481: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 249us/sample - loss: 12795.0762 - mean_absolute_error: 12795.0752 - val_loss: 20793.9336 - val_mean_absolute_error: 20793.9316
# Epoch 482/500
#  960/1168 [=======================>......] - ETA: 0s - loss: 14273.8031 - mean_absolute_error: 14273.8037
# Epoch 00482: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 250us/sample - loss: 14122.6815 - mean_absolute_error: 14122.6826 - val_loss: 21210.8972 - val_mean_absolute_error: 21210.8965
# Epoch 483/500
# 1120/1168 [===========================>..] - ETA: 0s - loss: 12698.0080 - mean_absolute_error: 12698.0078
# Epoch 00483: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 226us/sample - loss: 12632.5406 - mean_absolute_error: 12632.5410 - val_loss: 19103.5405 - val_mean_absolute_error: 19103.5410
# Epoch 484/500
# 1024/1168 [=========================>....] - ETA: 0s - loss: 12859.2416 - mean_absolute_error: 12859.2412
# Epoch 00484: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 235us/sample - loss: 12642.2818 - mean_absolute_error: 12642.2812 - val_loss: 20455.1256 - val_mean_absolute_error: 20455.1250
# Epoch 485/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 13058.1706 - mean_absolute_error: 13058.1699
# Epoch 00485: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 243us/sample - loss: 13083.2525 - mean_absolute_error: 13083.2510 - val_loss: 18688.6714 - val_mean_absolute_error: 18688.6738
# Epoch 486/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 13317.5737 - mean_absolute_error: 13317.5742
# Epoch 00486: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 238us/sample - loss: 13336.4983 - mean_absolute_error: 13336.4990 - val_loss: 19525.0139 - val_mean_absolute_error: 19525.0137
# Epoch 487/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 13691.2090 - mean_absolute_error: 13691.2090
# Epoch 00487: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 238us/sample - loss: 13456.7524 - mean_absolute_error: 13456.7529 - val_loss: 18535.5426 - val_mean_absolute_error: 18535.5430
# Epoch 488/500
# 1088/1168 [==========================>...] - ETA: 0s - loss: 13534.8290 - mean_absolute_error: 13534.8281
# Epoch 00488: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 229us/sample - loss: 13394.2593 - mean_absolute_error: 13394.2578 - val_loss: 18502.5185 - val_mean_absolute_error: 18502.5195
# Epoch 489/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 12485.1299 - mean_absolute_error: 12485.1299
# Epoch 00489: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 234us/sample - loss: 12618.8849 - mean_absolute_error: 12618.8857 - val_loss: 18985.8537 - val_mean_absolute_error: 18985.8535
# Epoch 490/500
# 1024/1168 [=========================>....] - ETA: 0s - loss: 15180.3037 - mean_absolute_error: 15180.3037
# Epoch 00490: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 238us/sample - loss: 14594.7941 - mean_absolute_error: 14594.7930 - val_loss: 19076.3172 - val_mean_absolute_error: 19076.3164
# Epoch 491/500
#  928/1168 [======================>.......] - ETA: 0s - loss: 17338.4181 - mean_absolute_error: 17338.4180
# Epoch 00491: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 233us/sample - loss: 16486.5439 - mean_absolute_error: 16486.5430 - val_loss: 20354.4285 - val_mean_absolute_error: 20354.4297
# Epoch 492/500
#  960/1168 [=======================>......] - ETA: 0s - loss: 12800.7441 - mean_absolute_error: 12800.7451
# Epoch 00492: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 256us/sample - loss: 12836.6681 - mean_absolute_error: 12836.6699 - val_loss: 19988.9228 - val_mean_absolute_error: 19988.9238
# Epoch 493/500
# 1056/1168 [==========================>...] - ETA: 0s - loss: 13274.8530 - mean_absolute_error: 13274.8545
# Epoch 00493: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 237us/sample - loss: 13594.0703 - mean_absolute_error: 13594.0713 - val_loss: 20252.1210 - val_mean_absolute_error: 20252.1211
# Epoch 494/500
#  992/1168 [========================>.....] - ETA: 0s - loss: 15677.4066 - mean_absolute_error: 15677.4053
# Epoch 00494: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 240us/sample - loss: 15352.3825 - mean_absolute_error: 15352.3818 - val_loss: 21811.6490 - val_mean_absolute_error: 21811.6465
# Epoch 495/500
# 1088/1168 [==========================>...] - ETA: 0s - loss: 13000.6131 - mean_absolute_error: 13000.6133
# Epoch 00495: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 233us/sample - loss: 13122.7146 - mean_absolute_error: 13122.7139 - val_loss: 20869.3279 - val_mean_absolute_error: 20869.3262
# Epoch 496/500
# 1152/1168 [============================>.] - ETA: 0s - loss: 13286.1762 - mean_absolute_error: 13286.1768
# Epoch 00496: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 268us/sample - loss: 13297.7530 - mean_absolute_error: 13297.7539 - val_loss: 20598.6235 - val_mean_absolute_error: 20598.6230
# Epoch 497/500
# 1024/1168 [=========================>....] - ETA: 0s - loss: 14599.4592 - mean_absolute_error: 14599.4580
# Epoch 00497: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 238us/sample - loss: 14636.7966 - mean_absolute_error: 14636.7949 - val_loss: 20592.8156 - val_mean_absolute_error: 20592.8145
# Epoch 498/500
#  896/1168 [======================>.......] - ETA: 0s - loss: 13738.0502 - mean_absolute_error: 13738.0527
# Epoch 00498: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 240us/sample - loss: 13312.2051 - mean_absolute_error: 13312.2061 - val_loss: 20210.8964 - val_mean_absolute_error: 20210.8965
# Epoch 499/500
#  992/1168 [========================>.....] - ETA: 0s - loss: 14753.1018 - mean_absolute_error: 14753.1006
# Epoch 00499: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 242us/sample - loss: 14185.9629 - mean_absolute_error: 14185.9629 - val_loss: 19796.7983 - val_mean_absolute_error: 19796.7988
# Epoch 500/500
#  928/1168 [======================>.......] - ETA: 0s - loss: 14518.0106 - mean_absolute_error: 14518.0117
# Epoch 00500: val_loss did not improve from 18242.63763
# 1168/1168 [==============================] - 0s 252us/sample - loss: 13823.2324 - mean_absolute_error: 13823.2334 - val_loss: 19914.9499 - val_mean_absolute_error: 19914.9492

# %%
# Load wights file of the best model :
wights_file = 'Weights-464--18242.63763.hdf5' # choose the best checkpoint 
model.load_weights(wights_file) # load it
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %% [markdown]
# We see that the validation loss of the best model is 18242.6376

# %% [markdown]
# ## Fourth : Test the model
# We will submit the predictions on the test data to folder and see how good our model is.

# %%
def make_submission(prediction, sub_name):
  my_submission = pd.DataFrame({'Id':pd.read_csv('test.csv').Id,'SalePrice':prediction})
  my_submission.to_csv('{}.csv'.format(sub_name),index=False)
  print('A submission file has been made')

# %%
predictions = model.predict(test)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
make_submission(predictions[:,0],'submission(NN).csv')
# Out:
# A submission file has been made

# %% [markdown]
# Not bad at all, with some more preprocessing, and more training, we can do better.

# %% [markdown]
# ## Fifth: Try another ML algorithms :
# Now, let us try another ML algorithm to compare the results.
#
# We will use random forest regressor and XGBRegressor.

# %% [markdown]
# **Split training data to training and validation data**

# %%
train_X, val_X, train_y, val_y = train_test_split(train, target, test_size = 0.25, random_state = 14)

# %% [markdown]
# **We will try Random forest model first.**

# %%
model = RandomForestRegressor()
model.fit(train_X,train_y)
# Out:
# RandomForestRegressor()

# %% [markdown]
# **Get the mean absolute error on the validation data **

# %%
predicted_prices = model.predict(val_X)
MAE = mean_absolute_error(val_y , predicted_prices)
print('Random forest validation MAE = ', MAE)
# Out:
# Random forest validation MAE =  17898.071598173516

# %% [markdown]
# **Make a submission file and submit it to folder to see the result.**

# %%
predicted_prices = model.predict(test)
make_submission(predicted_prices,'Submission(RF).csv')
# Out:
# A submission file has been made

# %% [markdown]
# **Now, let us try XGBoost model**

# %%
XGBModel = XGBRegressor()
XGBModel.fit(train_X,train_y , verbose=False)
# Out:
# [10:55:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %% [markdown]
# **Get the mean absolute error on the validation data**

# %%
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
# Out:
# XGBoost validation MAE =  17869.75410958904

# %% [markdown]
# **Make a submission file and submit it to folder to see the result.**

# %%
XGBpredictions = XGBModel.predict(test)
make_submission(XGBpredictions,'Submission(XGB).csv')
# Out:
# A submission file has been made

# %% [markdown]
# Isn't that a surprise, I really did not think that neural networks will beat random forests and XGBoost algorithms, but let us try not to be too optimistic, remember that we did not configure any hyperparameters on random forest and XGBoost models, I believe if we did so, these two models would outscore neural networks.
